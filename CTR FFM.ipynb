# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install turicreate

# %%
import turicreate as tc
from turicreate import load_sframe
from scipy.sparse import hstack
from sklearn.metrics import log_loss
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# # Preprocessing

# %%
data_frame = tc.SFrame.read_csv('/content/drive/My Drive/Colab Notebooks/train.csv')

# %%
data_frame.head(2)

# %% [markdown]
# ## Replace date & time with weekday & hour functions

# %%
def get_date(date):
    y = '20'+str(date)[:2]
    m = str(date)[2:4]
    d = str(date)[4:6]
    return y+'-'+m+'-'+d

# %%
def add_weekday_hour(data_frame):
    data_frame['weekday'] = data_frame['hour'].astype(str) \
    .apply(lambda x: get_date(x)).str_to_datetime().apply(lambda x: x.weekday())
    print('add_weekday_hour: half completed')
    data_frame['hour'] = data_frame['hour'].astype(str).apply(lambda x: x[6:]).astype(int)
    print('add_weekday_hour: completed')

# %% [markdown]
# ## Preprocess for train and test frames

# %%
test_frame = tc.SFrame.read_csv('/content/drive/My Drive/Colab Notebooks/test.csv')

# %%
add_weekday_hour(test_frame)

# %%
test_frame.save('/content/drive/My Drive/Colab Notebooks/test_sframe_with_hour_and_date', format='binary')

# %%
test_frame = load_sframe('/content/drive/My Drive/Colab Notebooks/test_sframe_with_hour_and_date')

# %%
data_frame.save('/content/drive/My Drive/Colab Notebooks/train_sframe_with_hour_and_date', format='binary')

# %%
data_frame = load_sframe('/content/drive/My Drive/Colab Notebooks/train_sframe_with_hour_and_date')

# %%
data_frame = load_sframe('/content/drive/My Drive/Colab Notebooks/train_sframe_encoded')

# %%
data_frame.head(2)

# %%
test_frame.head(10)

# %%
data_frame['device_id'].value_counts()
# Out:
# Columns:
# 	value	str
# 	count	int
#
# Rows: 2686408
#
# Data:
# +----------+----------+
# |  value   |  count   |
# +----------+----------+
# | a99f214a | 33358308 |
# | 0f7c61dc |  21356   |
# | c357dbff |  19667   |
# | 936e92fb |  13712   |
# | afeffc18 |   9654   |
# | 987552d1 |   4187   |
# | 28dc8687 |   4101   |
# | d857ffbb |   4004   |
# | cef4c8cc |   3694   |
# | b09da1c4 |   3655   |
# +----------+----------+
# [2686408 rows x 2 columns]
# Note: Only the head of the SFrame is printed.
# You can use print_rows(num_rows=m, num_columns=n) to print more rows and columns.

# %%
device_id_dummy = 'a99f214a'
def add_user_id(df):
  df['user_id'] = df.apply(lambda x: x['device_ip'] + x['device_model'] if x['device_id'] == device_id_dummy else x['device_id'])
  df.remove_columns(['device_ip', 'device_model', 'device_id'], inplace=True)

# %%
add_user_id(data_frame)

# %%
add_user_id(test_frame)

# %%
data_frame['app_id'].value_counts().sort('count', ascending=False)
# Out:
# Columns:
# 	value	str
# 	count	int
#
# Rows: 8552
#
# Data:
# +----------+----------+
# |  value   |  count   |
# +----------+----------+
# | ecad2386 | 25832830 |
# | 92f5800b | 1555283  |
# | e2fcccd2 | 1129016  |
# | febd1138 |  759098  |
# | 9c13b419 |  757812  |
# | 7358e05e |  615635  |
# | a5184c22 |  491457  |
# | d36838b1 |  457572  |
# | 685d1c4c |  408515  |
# | 54c5d545 |  397693  |
# +----------+----------+
# [8552 rows x 2 columns]
# Note: Only the head of the SFrame is printed.
# You can use print_rows(num_rows=m, num_columns=n) to print more rows and columns.

# %%
data_frame['site_id'].value_counts().sort('count', ascending=False)
# Out:
# Columns:
# 	value	str
# 	count	int
#
# Rows: 4737
#
# Data:
# +----------+----------+
# |  value   |  count   |
# +----------+----------+
# | 85f751fd | 14596137 |
# | 1fbe01fe | 6486150  |
# | e151e245 | 2637747  |
# | d9750ee7 |  963745  |
# | 5b08c53b |  913325  |
# | 5b4d2eda |  771360  |
# | 856e6d3f |  765891  |
# | a7853007 |  461311  |
# | b7e9786d |  369099  |
# | 5ee41ff2 |  349008  |
# +----------+----------+
# [4737 rows x 2 columns]
# Note: Only the head of the SFrame is printed.
# You can use print_rows(num_rows=m, num_columns=n) to print more rows and columns.

# %%
dummy_site_id = '85f751fd'
def make_app_frame(df):
  app_frame = df.filter_by([dummy_site_id], column_name='site_id')
  app_frame.remove_columns(['site_id', 'site_domain',
       'site_category'], inplace=True)
  return app_frame

def make_site_frame(df):
  site_frame = df.filter_by([dummy_site_id], column_name='site_id', exclude=True)
  site_frame.remove_columns(['app_id', 'app_domain', 'app_category'], inplace=True)
  return site_frame

def save_frames(frames_to_names, frame_type):
  for frame in frames_to_names:
    frame.save('/content/drive/My Drive/Colab Notebooks/{}_{}_frame'.format(frame_type, frames_to_names[frame]), format='binary')

def load_frames(frame_names, frame_type):
   return [load_sframe('/content/drive/My Drive/Colab Notebooks/{}_{}_frame'.format(frame_type, name)) for name in frame_names]

# %%
app_train_frame = make_app_frame(data_frame)
app_train_frame, app_valid_frame = app_train_frame.random_split(0.85)
app_test_frame =  make_app_frame(test_frame)

# %%
print(app_train_frame.head(1),app_valid_frame.head(1),app_test_frame.head(2))

# %%
print(app_train_frame.shape, app_valid_frame.shape, app_test_frame.shape)
# Out:
# (12405734, 20) (2190403, 20) (1719304, 19)

# %%
app_frames = {
    app_train_frame: 'train',
    app_valid_frame: 'valid',
    app_test_frame: 'test'
}
save_frames(frames, 'app')

# %%
app_train_frame, app_valid_frame, app_test_frame = load_frames(['train', 'valid', 'test'], 'app')

# %%
site_train_frame = make_site_frame(data_frame)
print('site train frame created')
site_train_frame, site_valid_frame = site_train_frame.random_split(0.85)
print('site valid frame created')
site_test_frame =  make_site_frame(test_frame)
print('site test frame created')
# Out:
# site train frame created
# site valid frame created
# site test frame created

# %%
print(site_train_frame.head(1), site_valid_frame.head(1), site_test_frame.head(2))
print(site_train_frame.shape, site_valid_frame.shape, site_test_frame.shape)

# %%
site_frames = {
    site_train_frame: 'train',
    site_valid_frame: 'valid',
    site_test_frame: 'test'
}
save_frames(site_frames, 'site')

# %%
site_train_frame, site_valid_frame, site_test_frame = load_frames(['train', 'valid', 'test'], 'site')

# %% [markdown]
# ## Convert to libffm format

# %%
from bisect import bisect_left


class EncodeDataFrame:

  def __init__(self, df, valid_frame, test_frame):
    self.df = df
    self.valid_frame = valid_frame
    self.test_frame = test_frame
    self.dictionary_fields = {}
    for i in range(2, self.df.shape[1]):
      self.dictionary_fields[self.df.column_names()[i]] = i;
    self.cur_min = 50
    self.features_dict = {}

   
  def encode_feature(self, column, border):
    column_name = self.df.column_names()[column]

    self.feature_frame = self.df[column_name].value_counts().sort('count', ascending=True)

    last_ind = bisect_left(list(self.feature_frame['count']), border)
    encoding_column = [column] * last_ind
    new_min = self.cur_min + self.feature_frame.shape[0] - last_ind
    encoding_column.extend(list(range(self.cur_min, new_min)))
    self.cur_min = new_min
    print('total unique features values: {}, rejected: {}'.format(self.feature_frame.shape[0], last_ind))
    self.feature_frame.remove_column('count', inplace=True)
    self.feature_frame.add_column(tc.SArray(encoding_column), column_name='encoding', inplace=True)
    self.features_dict = self.feature_frame.to_dataframe().set_index('value').to_dict(orient='dict')['encoding']
    self.df[column_name] = self.df[column_name].apply(lambda x: self.features_dict[x])
    

  def encode_logger(self, column, x):
    if x in self.features_dict:
      return self.features_dict[x]
    else:
      print('value {} in {} column not found'.format(x, column))
      return column

  def encode_feature_test_valid(self, df, column):
    column_name = df.column_names()[column]
    df[column_name] = df[column_name].apply(lambda x: self.encode_logger(column, x))
      
  def encode_dataframe(self, border = 0):
    step = 1
    for i in range(2, self.df.shape[1], step):
      self.features_dict = {}
      for column in range(i, min(i + step, self.df.shape[1])):    
        self.encode_feature(column, border=border)
      print('encode_dataframe:', column, 'column done, cur min =', self.cur_min)

      for column in range(i, min(i + step, self.valid_frame.shape[1])):
        self.encode_feature_test_valid(self.valid_frame, column)
      print('encode_dataframe valid:', column, 'column done.')

      for column in range(i - 1, min(i + step - 1, self.test_frame.shape[1])):  
        self.encode_feature_test_valid(self.test_frame, column)
      print('encode_dataframe test:', column, 'column done.')

  def convert_and_save_frame_libffm_format(self, frame, name, frame_type):
    frame = frame.remove_column('id')
    for column in frame.column_names()[1:]:
      frame[column] = frame[column].apply(lambda x: str(self.dictionary_fields[column]) + ':' + str(x) + ':1') 
    print(name, 'dataframe converting done')
    frame.export_csv('/content/drive/My Drive/Colab Notebooks/libffm_format_{}_{}.csv'.format(frame_type, name), delimiter=' ', header=False)
    print(name, 'dataframe exported')
    

  def convert_to_libffm_format(self, frame_type):
    self.convert_and_save_frame_libffm_format(self.df, 'train', frame_type)
    self.convert_and_save_frame_libffm_format(self.valid_frame, 'vоalid', frame_type)
    self.convert_and_save_frame_libffm_format(self.test_frame, 'test', frame_type)

# %%
app_encoder = EncodeDataFrame(app_train_frame, app_valid_frame, app_test_frame)

# %%
app_encoder.encode_dataframe(border=2)
# Out:
# total features: 24, rejected features: 0
# encode_dataframe: 2 column done, cur min = 74
# encode_dataframe valid: 2 column done.
# encode_dataframe test: 1 column done.
# total features: 7, rejected features: 0
# encode_dataframe: 3 column done, cur min = 81
# encode_dataframe valid: 3 column done.
# encode_dataframe test: 2 column done.
# total features: 6, rejected features: 0
# encode_dataframe: 4 column done, cur min = 87
# encode_dataframe valid: 4 column done.
# encode_dataframe test: 3 column done.
# total features: 8291, rejected features: 1655
# encode_dataframe: 5 column done, cur min = 6723
# encode_dataframe valid: 5 column done.
# encode_dataframe test: 4 column done.
# total features: 541, rejected features: 129
# encode_dataframe: 6 column done, cur min = 7135
# encode_dataframe valid: 6 column done.
# encode_dataframe test: 5 column done.
# total features: 35, rejected features: 3
# encode_dataframe: 7 column done, cur min = 7167
# encode_dataframe valid: 7 column done.
# encode_dataframe test: 6 column done.
# total features: 4, rejected features: 0
# encode_dataframe: 8 column done, cur min = 7171
# encode_dataframe valid: 8 column done.
# encode_dataframe test: 7 column done.
# total features: 4, rejected features: 0
# encode_dataframe: 9 column done, cur min = 7175
# encode_dataframe valid: 9 column done.
# encode_dataframe test: 8 column done.
# total features: 2242, rejected features: 73
# encode_dataframe: 10 column done, cur min = 9344
# encode_dataframe valid: 10 column done.
# encode_dataframe test: 9 column done.
# total features: 8, rejected features: 0
# encode_dataframe: 11 column done, cur min = 9352
# encode_dataframe valid: 11 column done.
# encode_dataframe test: 10 column done.
# total features: 9, rejected features: 0
# encode_dataframe: 12 column done, cur min = 9361
# encode_dataframe valid: 12 column done.
# encode_dataframe test: 11 column done.
# total features: 367, rejected features: 5
# encode_dataframe: 13 column done, cur min = 9723
# encode_dataframe valid: 13 column done.
# encode_dataframe test: 12 column done.
# total features: 4, rejected features: 0
# encode_dataframe: 14 column done, cur min = 9727
# encode_dataframe valid: 14 column done.
# encode_dataframe test: 13 column done.
# total features: 63, rejected features: 0
# encode_dataframe: 15 column done, cur min = 9790
# encode_dataframe valid: 15 column done.
# encode_dataframe test: 14 column done.
# total features: 170, rejected features: 3
# encode_dataframe: 16 column done, cur min = 9957
# encode_dataframe valid: 16 column done.
# encode_dataframe test: 15 column done.
# total features: 55, rejected features: 0
# encode_dataframe: 17 column done, cur min = 10012
# encode_dataframe valid: 17 column done.
# encode_dataframe test: 16 column done.
# total features: 7, rejected features: 0
# encode_dataframe: 18 column done, cur min = 10019
# encode_dataframe valid: 18 column done.
# encode_dataframe test: 17 column done.
# total features: 3670333, rejected features: 2200163
# encode_dataframe: 19 column done, cur min = 1480189
# value 42f455c70712b55e in 19 column not found
# value 90f4d28057b3c6c3 in 19 column not found
# value 556a65e5 in 19 column not found
# value 9eb9a972 in 19 column not found
# value fc04323d in 19 column not found
# value ccf5f4a1 in 19 column not found
# value 01d995aa in 19 column not found
# value 9bff884b in 19 column not found
# value e0944c0d in 19 column not found
# value c9de05b3cbb77256 in 19 column not found
# value 5c170bf5aad45b01 in 19 column not found
# value 71d816932ea4f8ba in 19 column not found
# value 6fce88248803c3d6 in 19 column not found
# value 254704b5 in 19 column not found
# value 2a6fe2a5 in 19 column not found
# value 1fe464c272a00661 in 19 column not found
# value f752a51105b9fa1b in 19 column not found
# value db0ba2cc in 19 column not found
# value 18246a01 in 19 column not found
# value 9146e9fdeb9d69e8 in 19 column not found
# value 31eb4622cb82c508 in 19 column not found
# value d1ade92e1f0bc64f in 19 column not found
# value 2b4413d184dda655 in 19 column not found
# value dc4aa6fc in 19 column not found
# value 6a008a3a in 19 column not found
# value 290090a4 in 19 column not found
# value e2b9f6ab8f1db0bc in 19 column not found
# value 2a4c740d945dd5c4 in 19 column not found
# value a206259b78d9bd10 in 19 column not found
# value 68b7b56b in 19 column not found
# value e0f70006 in 19 column not found
# encode_dataframe valid: 19 column done.
# value 078c6b381f0bc64f in 18 column not found
# value 9100054ec6263d8a in 18 column not found
# value c52a0887ecb851b2 in 18 column not found
# value d71e73c09a45a8e8 in 18 column not found
# value f551f9a0 in 18 column not found
# value b12870e11f0bc64f in 18 column not found
# value e37b2b10f39b265e in 18 column not found
# value 0d5d53fc in 18 column not found
# value 0b643af8d787e91b in 18 column not found
# value 64d7d7d18a4875bd in 18 column not found
# value 8190c1fe2ea4f8ba in 18 column not found
# value 4291198c2d08e606 in 18 column not found
# value e58c0a80192f98c4 in 18 column not found
# value ec9f27f2649e7a14 in 18 column not found
# value cc9b5137a4b6f65b in 18 column not found
# value 1534868d1f0bc64f in 18 column not found
# value 605cf2b99b5ce758 in 18 column not found
# value c35ec1b32cd8b8ab in 18 column not found
# value 58913c2136b67a2a in 18 column not found
# value e2bc6c93 in 18 column not found
# value de3591bcaad45b01 in 18 column not found
# value fb3dd181 in 18 column not found
# value 314f5742dc739d1a in 18 column not found
# value 1ed7239f7abbbd5c in 18 column not found
# value a817c4cece576f14 in 18 column not found
# value 7296ff327a044878 in 18 column not found
# value 9c813ea76d44e29a in 18 column not found
# value ff2c57ed in 18 column not found
# value f85dd1a4a5bce124 in 18 column not found
# value 3ef09bc81f0bc64f in 18 column not found
# value 408727289b5ce758 in 18 column not found
# value 355dde08 in 18 column not found
# value 268823c89b5ce758 in 18 column not found
# value 6167b1b1d31a172e in 18 column not found
# value 55debb21bc8f5d71 in 18 column not found
# value ca77835caf7fe221 in 18 column not found
# value 30a3b3deb4b19c97 in 18 column not found
# value c4f987b01f0bc64f in 18 column not found
# value 57d49da0df36cdb8 in 18 column not found
# value 8e6abea8 in 18 column not found
# value a2b17167 in 18 column not found
# value 24f9932a2ea4f8ba in 18 column not found
# value 654438b3ecb851b2 in 18 column not found
# value e8ab5e8899e427c9 in 18 column not found
# value 264b2e67526fa832 in 18 column not found
# encode_dataframe test: 18 column done.

# %%
app_frames = {
    app_train_frame: 'train_encoded',
    app_valid_frame: 'valid_encoded',
    app_test_frame: 'test_encoded'
}
save_frames(frames, 'app')

# %%
app_encoder.convert_to_libffm_format('app')
# Out:
# train dataframe converting done
# train dataframe exported
# valid dataframe converting done
# valid dataframe exported
# test dataframe converting done
# test dataframe exported

# %%
site_encoder = EncodeDataFrame(site_train_frame, site_valid_frame, site_test_frame)

# %%
site_encoder.encode_dataframe(border=5)
# Out:
# total unique features values: 24, rejected: 0
# encode_dataframe: 2 column done, cur min = 74
# encode_dataframe valid: 2 column done.
# encode_dataframe test: 1 column done.
# total unique features values: 5, rejected: 0
# encode_dataframe: 3 column done, cur min = 79
# encode_dataframe valid: 3 column done.
# encode_dataframe test: 2 column done.
# total unique features values: 5, rejected: 0
# encode_dataframe: 4 column done, cur min = 84
# encode_dataframe valid: 4 column done.
# encode_dataframe test: 3 column done.
# total unique features values: 4652, rejected: 1185
# encode_dataframe: 5 column done, cur min = 3551
# encode_dataframe valid: 5 column done.
# encode_dataframe test: 4 column done.
# total unique features values: 7450, rejected: 3304
# encode_dataframe: 6 column done, cur min = 7697
# encode_dataframe valid: 6 column done.
# encode_dataframe test: 5 column done.
# total unique features values: 26, rejected: 3
# encode_dataframe: 7 column done, cur min = 7720
# encode_dataframe valid: 7 column done.
# encode_dataframe test: 6 column done.
# total unique features values: 5, rejected: 0
# encode_dataframe: 8 column done, cur min = 7725
# encode_dataframe valid: 8 column done.
# encode_dataframe test: 7 column done.
# total unique features values: 2, rejected: 0
# encode_dataframe: 9 column done, cur min = 7727
# encode_dataframe valid: 9 column done.
# encode_dataframe test: 8 column done.
# total unique features values: 2033, rejected: 177
# encode_dataframe: 10 column done, cur min = 9583
# encode_dataframe valid: 10 column done.
# encode_dataframe test: 9 column done.
# total unique features values: 5, rejected: 0
# encode_dataframe: 11 column done, cur min = 9588
# encode_dataframe valid: 11 column done.
# encode_dataframe test: 10 column done.
# total unique features values: 6, rejected: 0
# encode_dataframe: 12 column done, cur min = 9594
# encode_dataframe valid: 12 column done.
# encode_dataframe test: 11 column done.
# total unique features values: 351, rejected: 3
# encode_dataframe: 13 column done, cur min = 9942
# encode_dataframe valid: 13 column done.
# encode_dataframe test: 12 column done.
# total unique features values: 4, rejected: 0
# encode_dataframe: 14 column done, cur min = 9946
# encode_dataframe valid: 14 column done.
# encode_dataframe test: 13 column done.
# total unique features values: 55, rejected: 0
# encode_dataframe: 15 column done, cur min = 10001
# encode_dataframe valid: 15 column done.
# encode_dataframe test: 14 column done.
# total unique features values: 170, rejected: 6
# encode_dataframe: 16 column done, cur min = 10165
# encode_dataframe valid: 16 column done.
# encode_dataframe test: 15 column done.
# total unique features values: 56, rejected: 0
# encode_dataframe: 17 column done, cur min = 10221
# encode_dataframe valid: 17 column done.
# encode_dataframe test: 16 column done.
# total unique features values: 7, rejected: 0
# encode_dataframe: 18 column done, cur min = 10228
# encode_dataframe valid: 18 column done.
# encode_dataframe test: 17 column done.
# total unique features values: 7246710, rejected: 6393177
# encode_dataframe: 19 column done, cur min = 863761
# value 07f3950949ea3580 in 19 column not found
# value 08dd2eb8cdf6ea96 in 19 column not found
# value 7768930f272ca818 in 19 column not found
# value 9906e40c in 19 column not found
# value 40b43f443fecb32a in 19 column not found
# value 8ea670e2f186d2e8 in 19 column not found
# value 8e195da98a4875bd in 19 column not found
# value b5ab1f7d8a4875bd in 19 column not found
# value c1cbf73f4ea23a13 in 19 column not found
# value 66575ef61f883dc7 in 19 column not found
# value 0b416039a99bdcb1 in 19 column not found
# value 4c99affe99115329 in 19 column not found
# value 20219b545096d134 in 19 column not found
# value 77b47d08 in 19 column not found
# value 5b29b07705b9fa1b in 19 column not found
# value ec0b54e6375c3d47 in 19 column not found
# encode_dataframe valid: 19 column done.
# value e75922ff68b6db2c in 18 column not found
# value f1e8683dd4897fef in 18 column not found
# value 2d4180b28a4875bd in 18 column not found
# value f43d90251ccc7835 in 18 column not found
# value c3113588 in 18 column not found
# value 52260ad2 in 18 column not found
# value 5f4480c87e4efdcd in 18 column not found
# value 747269b77ac6007f in 18 column not found
# value 1cbce882635623a9 in 18 column not found
# value c0fcb2dc3f3d3fa8 in 18 column not found
# value 5c9c044a in 18 column not found
# value 0550be60dff23b13 in 18 column not found
# value dd59b6d4d787e91b in 18 column not found
# value f4287d504ea23a13 in 18 column not found
# value 612b974c1ccc7835 in 18 column not found
# value 9c19c95c1c6a881d in 18 column not found
# value 2b3c27b3d31a172e in 18 column not found
# value 65b8bb5cbe6db1d7 in 18 column not found
# value 6ac8bc91fed5ad55 in 18 column not found
# value 6650ce8776dc4769 in 18 column not found
# value 3c3e828c9c7b6730 in 18 column not found
# value 8525e67e6569eeb3 in 18 column not found
# value 44239568 in 18 column not found
# value d7b195def1c7e892 in 18 column not found
# value cfd5b925d25693ce in 18 column not found
# value 77ee7b08be6db1d7 in 18 column not found
# value b24f5498ecb851b2 in 18 column not found
# value d1954f6d6332421a in 18 column not found
# value f2c21377d787e91b in 18 column not found
# value f5e5de10cdfde03b in 18 column not found
# value ddf90e5f8a4875bd in 18 column not found
# value 07d906ded4897fef in 18 column not found
# value 55b3ed53d57111ae in 18 column not found
# value 5112c331a0f5f879 in 18 column not found
# value 80ad714a36b67a2a in 18 column not found
# value ff2aa005684581ce in 18 column not found
# value 693c54a3d8337869 in 18 column not found
# value c1fa394f8ce34352 in 18 column not found
# value 03bc72cafce66524 in 18 column not found
# value e80700e723885c9e in 18 column not found
# value 8894d62e3fecb32a in 18 column not found
# value a9ab8da525e362e2 in 18 column not found
# value 2c5b931cd2e5a0b2 in 18 column not found
# value 642eafdb in 18 column not found
# value 489c0e027abbbd5c in 18 column not found
# value 603878c1c4cff2ea in 18 column not found
# value b9df39907abbbd5c in 18 column not found
# encode_dataframe test: 18 column done.

# %%
site_frames = {
    site_train_frame: 'train_encoded',
    site_valid_frame: 'valid_encoded',
    site_test_frame: 'test_encoded'
}
save_frames(site_frames, 'site')

# %%
site_train_frame, site_valid_frame, site_test_frame = load_frames(['train_encoded', 'valid_encoded', 'test_encoded'], 'site')

# %%
print(site_encoder.df.head(1), site_encoder.valid_frame.head(1), site_encoder.test_frame.head(2))
print(site_encoder.df.shape,  site_encoder.valid_frame.shape, site_encoder.test_frame.shape)

# %%
site_encoder.convert_to_libffm_format('site')
# Out:
# train dataframe converting done
# train dataframe exported
# valid dataframe converting done
# valid dataframe exported
# test dataframe converting done
# test dataframe exported

# %% [markdown]
# ## Compose

# %%
dummy_site_id = '85f751fd'
eps = 10 ** -7

def get_frame_results(frame_type):
  test_frame = load_sframe('/content/drive/My Drive/Colab Notebooks/{frame_type}_test_frame'.format(frame_type=frame_type))
  results_frame = test_frame[['id']].to_dataframe()
  results_frame['click'] = tc.SFrame.read_csv('/content/drive/My Drive/Colab Notebooks/result_{frame_type}.csv'.format(frame_type=frame_type),
                                              header=False)['X1'].apply(lambda x: min(max(x, eps), 1 - eps))
  print(frame_type, 'processed')
  return results_frame

def predict():
  results_frame = get_frame_results('site')
  return results_frame.append(get_frame_results('app'))

# %%
results_frame = predict()
results_frame

# %%
results_frame.to_csv('/content/drive/My Drive/Colab Notebooks/results_frame_ffm.csv.gz', compression='gzip', index=False)
